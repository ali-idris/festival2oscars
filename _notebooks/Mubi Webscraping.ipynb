# %%
# Standard imports
import numpy as np
import pandas as pd

# For web scraping
import requests
from bs4 import BeautifulSoup

# For performing regex operations
import re

# For adding delays so that we don't spam requests
import time

# %%
url = 'https://mubi.com/awards-and-festivals'

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
response.content
# Out:
# b'<!DOCTYPE html><html lang="en"><head><link rel="preload" href="https://assets.mubicdn.net/static/fonts/DMSans-Regular.ttf" as="font" crossorigin="anonymous"/><link rel="preload" href="https://assets.mubicdn.net/static/fonts/DMSans-Bold.ttf" as="font" crossorigin="anonymous"/><link rel="preload" href="https://assets.mubicdn.net/static/fonts/DMSans-Italic.ttf" as="font" crossorigin="anonymous"/><link rel="preload" href="https://assets.mubicdn.net/static/fonts/DMSans-MediumItalic.ttf" as="font" crossorigin="anonymous"/><link rel="preload" href="https://assets.mubicdn.net/static/fonts/DMSans-BoldItalic.ttf" as="font" crossorigin="anonymous"/><meta name="viewport" content="width=device-width"/><meta charSet="utf-8"/><title>List of awards and festivals on MUBI</title><link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/><meta content="app-id=626148774" name="apple-itunes-app"/><link href="/apple-touch-icon.png?ver=2" rel="apple-touch-icon"/><meta name="description" content="
# ...

# %%
soup = BeautifulSoup(response.content)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link as="font" crossorigin="anonymous" href="https://assets.mubicdn.net/static/fonts/DMSans-Regular.ttf" rel="preload"/>
#   <link as="font" crossorigin="anonymous" href="https://assets.mubicdn.net/static/fonts/DMSans-Bold.ttf" rel="preload"/>
#   <link as="font" crossorigin="anonymous" href="https://assets.mubicdn.net/static/fonts/DMSans-Italic.ttf" rel="preload"/>
#   <link as="font" crossorigin="anonymous" href="https://assets.mubicdn.net/static/fonts/DMSans-MediumItalic.ttf" rel="preload"/>
#   <link as="font" crossorigin="anonymous" href="https://assets.mubicdn.net/static/fonts/DMSans-BoldItalic.ttf" rel="preload"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta charset="utf-8"/>
#   <title>
#    List of awards and festivals on MUBI
#   </title>
#   <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <meta content="app-id=626148774" name="apple-itunes-app"/>
# ...

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup.title.text
# Out:
# 'List of awards and festivals on MUBI'

# %%
soup.find('li', class_='css-2efj4a exm3nmc0').text
# Out:
# ''

# %%
soup.find('div', class_='css-cmn4n4 etabiqi1').text
# Out:
# ''

# %%
soup.find('div', class_='css-1qpeh2n eq94xd12').text
# Out:
# 'Try 7 Days FreeNow ShowingNotebookMUBI GOSHOPGift MUBIAboutWays to WatchStudentsJobsTerms & PrivacyHelpLog InNow ShowingNotebookMUBI GOLog InTry 7 Days FreeNow ShowingNotebookMUBI GOSHOPGift MUBIAboutWays to WatchStudentsJobsTerms & PrivacyHelpBROWSEBrowse genres. Or directors. Or double-award-winners. Find films you didn’t know you were looking for.FilmsCast & CrewCastListsAwards & FestivalsFestivalsAll eventsFestivalAwardsSort by: RecommendedA-Z'

# %%
soup.find('div', class_='css-sobyq0 e1lbr4rc2').text
# Out:
# 'BROWSEBrowse genres. Or directors. Or double-award-winners. Find films you didn’t know you were looking for.'

# %%
soup.find('div', class_='css-1uvre92 e1qpe7285').text
# Out:
# 'FilmsCast & CrewCastListsAwards & FestivalsFestivals'

# %%
soup.find('div', class_='css-1ma0nfe en8arq1').text
# Out:
# 'We use cookies to ensure that we give you the best experience on our website. Click here for more information.AcceptReject'

# %%
soup.find('li', class_='css-2efj4a exm3nmc0')
# Out:
# <li class="css-2efj4a exm3nmc0"><style data-emotion="css 10j12cj">.css-10j12cj{width:100%;height:85px;}</style><div class="css-10j12cj epusewd0" height="85px"></div></li>
