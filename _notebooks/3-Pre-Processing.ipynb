# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# Filter warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Below I am setting 'df' to our cleaned airline dataset & viewing the first 2 rows
df = pd.read_csv('../data/cleaned_airlines.csv')
df.head(2)
# Out:
#    Unnamed: 0      id satisfaction_target customer_gender  \
# 0           0  117135           Satisfied            Male
# 1           1   72091           Satisfied            Male
#
#   customer_loyalty_type  customer_age customer_travel_type  \
# 0              Disloyal            56             Personal
# 1              Disloyal            49             Personal
#
#   customer_class_type  flight_distance  flight_wifi_satisfaction_rating  ...  \
# 0             Economy              369                                0  ...
# 1             Economy             2486                                0  ...
#
#    seat_comfort_satisfaction_rating  \
# 0                                 3
# 1                                 3
#
#    inflight_entertainment_satisfaction_rating  \
# 0                                           3
# 1                                           2
#
#    onboard_service_satisfaction_rating  leg_room_satisfaction_rating  \
# 0                                    1                             5
# 1                                    1                             1
#
#    baggage_handling_satisfaction_rating  checkin_service_satisfaction_rating  \
# 0                                     3                                    3
# 1                                     4                                    4
#
#    inflight_service_satisfaction_rating  cleanliness_satisfaction_rating  \
# 0                                     4                                3
# 1                                     3                                2
#
#    departure_delay_in_minutes  arrival_delay_in_minutes
# 0                           0                       0.0
# 1                           0                       0.0
#
# [2 rows x 25 columns]

# %%
df = df.drop('Unnamed: 0', axis=1)
df= df.drop('id', axis=1)

# %%
df.head(2)
# Out:
#   satisfaction_target customer_gender customer_loyalty_type  customer_age  \
# 0           Satisfied            Male              Disloyal            56
# 1           Satisfied            Male              Disloyal            49
#
#   customer_travel_type customer_class_type  flight_distance  \
# 0             Personal             Economy              369
# 1             Personal             Economy             2486
#
#    flight_wifi_satisfaction_rating  \
# 0                                0
# 1                                0
#
#    departure/arrival_time_satisfaction_rating  \
# 0                                           2
# 1                                           2
#
#    online_booking_satisfaction_rating  ...  seat_comfort_satisfaction_rating  \
# 0                                   0  ...                                 3
# 1                                   1  ...                                 3
#
#    inflight_entertainment_satisfaction_rating  \
# 0                                           3
# 1                                           2
#
#    onboard_service_satisfaction_rating  leg_room_satisfaction_rating  \
# 0                                    1                             5
# 1                                    1                             1
#
#    baggage_handling_satisfaction_rating  checkin_service_satisfaction_rating  \
# 0                                     3                                    3
# 1                                     4                                    4
#
#    inflight_service_satisfaction_rating  cleanliness_satisfaction_rating  \
# 0                                     4                                3
# 1                                     3                                2
#
#    departure_delay_in_minutes  arrival_delay_in_minutes
# 0                           0                       0.0
# 1                           0                       0.0
#
# [2 rows x 23 columns]

# %%
gender_dummies = pd.get_dummies(df.satisfaction_target,  prefix = 'satisfaction_target').iloc[:,1:]
df = pd.concat([df, gender_dummies], axis=1)

gender_dummies = pd.get_dummies(df.customer_gender,  prefix = 'customer_gender').iloc[:,1:]
df = pd.concat([df, gender_dummies], axis=1)

gender_dummies = pd.get_dummies(df.customer_loyalty_type,  prefix = 'customer_loyalty_type').iloc[:,1:]
df = pd.concat([df, gender_dummies], axis=1)

gender_dummies = pd.get_dummies(df.customer_travel_type,  prefix = 'customer_travel_type').iloc[:,1:]
df = pd.concat([df, gender_dummies], axis=1)

gender_dummies = pd.get_dummies(df.customer_class_type,  prefix = 'customer_class_type').iloc[:,1:]
df = pd.concat([df, gender_dummies], axis=1)

# %%
df.head(2)
# Out:
#   satisfaction_target customer_gender customer_loyalty_type  customer_age  \
# 0           Satisfied            Male              Disloyal            56
# 1           Satisfied            Male              Disloyal            49
#
#   customer_travel_type customer_class_type  flight_distance  \
# 0             Personal             Economy              369
# 1             Personal             Economy             2486
#
#    flight_wifi_satisfaction_rating  \
# 0                                0
# 1                                0
#
#    departure/arrival_time_satisfaction_rating  \
# 0                                           2
# 1                                           2
#
#    online_booking_satisfaction_rating  ...  \
# 0                                   0  ...
# 1                                   1  ...
#
#    inflight_service_satisfaction_rating  cleanliness_satisfaction_rating  \
# 0                                     4                                3
# 1                                     3                                2
#
#    departure_delay_in_minutes  arrival_delay_in_minutes  \
# 0                           0                       0.0
# 1                           0                       0.0
#
#    satisfaction_target_Satisfied  customer_gender_Male  \
# 0                              1                     1
# 1                              1                     1
#
#    customer_loyalty_type_Loyal  customer_travel_type_Personal  \
# 0                            0                              1
# 1                            0                              1
#
#    customer_class_type_Economy  customer_class_type_Economy Plus
# 0                            1                                 0
# 1                            1                                 0
#
# [2 rows x 29 columns]

# %%
df = df.drop('satisfaction_target', axis=1)
df= df.drop('customer_gender', axis=1)
df = df.drop('customer_loyalty_type', axis=1)
df = df.drop('customer_travel_type', axis=1)
df= df.drop('customer_class_type', axis=1)

# %%
df.head(2)
# Out:
#    customer_age  flight_distance  flight_wifi_satisfaction_rating  \
# 0            56              369                                0
# 1            49             2486                                0
#
#    departure/arrival_time_satisfaction_rating  \
# 0                                           2
# 1                                           2
#
#    online_booking_satisfaction_rating  gate_location_satisfaction_rating  \
# 0                                   0                                  4
# 1                                   1                                  4
#
#    food/drink_satisfaction_rating  online_boarding_satisfaction_rating  \
# 0                               3                                    0
# 1                               2                                    1
#
#    seat_comfort_satisfaction_rating  \
# 0                                 3
# 1                                 3
#
#    inflight_entertainment_satisfaction_rating  ...  \
# 0                                           3  ...
# 1                                           2  ...
#
#    inflight_service_satisfaction_rating  cleanliness_satisfaction_rating  \
# 0                                     4                                3
# 1                                     3                                2
#
#    departure_delay_in_minutes  arrival_delay_in_minutes  \
# 0                           0                       0.0
# 1                           0                       0.0
#
#    satisfaction_target_Satisfied  customer_gender_Male  \
# 0                              1                     1
# 1                              1                     1
#
#    customer_loyalty_type_Loyal  customer_travel_type_Personal  \
# 0                            0                              1
# 1                            0                              1
#
#    customer_class_type_Economy  customer_class_type_Economy Plus
# 0                            1                                 0
# 1                            1                                 0
#
# [2 rows x 24 columns]

# %%
df.shape
# Out:
# (129880, 24)

# %%
df.to_csv('../data/very_train_cleaned_airlines.csv')

# %%
from sklearn.model_selection import train_test_split

# %%
# Below I am setting our train dataset target y to 'rating'
y = df['satisfaction_target_Satisfied']

# Below I am setting our train dataset data to every column besides 'rating'
X = df.drop('satisfaction_target_Satisfied', axis = 1)

# %%
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size = 0.3,
            random_state=1)

# %%
X_train.shape
# Out:
# (90916, 23)

# %%
X_test.shape
# Out:
# (38964, 23)

# %%
X_train.to_csv('../data/train_cleaned_airlines.csv')

# %%
X_test.to_csv('../data/test_cleaned_airlines.csv')
